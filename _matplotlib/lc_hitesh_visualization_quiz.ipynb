# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [1, 2, 3], linestyle='dotted')
plt.show()

# %%
L=[63,65,67,69,69,70,71,71,73,74,74,75,77,77,83,85,87] 
plt.boxplot(L, vert = False) 
plt.show()

# %%
a=['apple','banana','orange','mango','pinapple','grapes'] 
b=[120,340,200,150,60,300] 
plt.pie(b,labels = a,  autopct = '%1.1f%%') 
plt.show()
