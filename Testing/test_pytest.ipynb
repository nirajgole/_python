# %% [markdown]
# ### PyTest

# %%
# !pip install pytest ipytest
import ipytest
ipytest.autoconfig()

# %%
# define a function two add two integers
def add_two_numbers(a:int, b:int) -> int:
    """
    This function takes two numbers as input and returns their sum.

    :param a: First number
    :param b: Second number
    :return: Sum of a and b
    """
    return a + b

# %%
# write a test to check addition of two integers
def test_add():
    result = add_two_numbers(2,3)
    assert result==10

# %%
ipytest.run('-vv')  # '-vv' for increased verbosity
# Out:
# ======================================= test session starts =======================================
# platform win32 -- Python 3.11.3, pytest-8.3.5, pluggy-1.5.0 -- c:\Users\Gigabyte\AppData\Local\Programs\Python\Python311\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\Gigabyte\Desktop\_python\Testing
# collecting ... collected 1 item
#
# t_4cf1b278ab214f4790065d4286470f52.py::test_add FAILED                                       [100%]
#
# ============================================ FAILURES =============================================
# ____________________________________________ test_add _____________________________________________
#
#     def test_add():
#         result = add_two_numbers(2,3)
# >       assert result==10
# E       assert 5 == 10
#
# C:\Users\Gigabyte\AppData\Local\Temp\ipykernel_20456\1652916820.py:4: AssertionError
# ===================================== short test summary info =====================================
# FAILED t_4cf1b278ab214f4790065d4286470f52.py::test_add - assert 5 == 10
# ======================================== 1 failed in 0.25s ========================================
# <ExitCode.TESTS_FAILED: 1>
